# %%
import json

def load_data(filename):
    with open(filename, "r") as file:
        return json.load(file)

def find_people_you_may_know(user_id, data):
    user_friends = {}
    for user in data["users"]:
        user_friends[user["id"]] = set(user["friends"])
    
    if user_id not in user_friends:
        return []
    
    direct_friends = user_friends[user_id]
    suggestions = {}
    
    for friend in direct_friends:
        # For all friends of friend
        for mutual in user_friends[friend]:
            # If mutual id is not the same user and not already a direct friend of user
            if mutual != user_id and mutual not in direct_friends:
                # Count mutual friends
                suggestions[mutual] = suggestions.get(mutual, 0) + 1
    
    sorted_suggestions = sorted(suggestions.items(), key=lambda x: x[1], reverse=True)
    return [user_id for user_id, _ in sorted_suggestions]

# Load data
data = load_data("cleaned_codebook_data.json")
user_id = 1  # Example: Finding suggestions for Amit
recommendations = find_people_you_may_know(user_id, data)
print(f"People You May Know for User {user_id}: {recommendations}")
# Out:
# ----------------------------------------------------------------------
# FileNotFoundError                    Traceback (most recent call last)
# Cell In[1], line 30
#      27     return [user_id for user_id, _ in sorted_suggestions]
#      29 # Load data
# ---> 30 data = load_data("cleaned_codebook_data.json")
#      31 user_id = 1  # Example: Finding suggestions for Amit
#      32 recommendations = find_people_you_may_know(user_id, data)
#
# Cell In[1], line 4, in load_data(filename)
#       3 def load_data(filename):
# ----> 4     with open(filename, "r") as file:
#       5         return json.load(file)
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'cleaned_codebook_data.json'

# %%
import json
import os

def load_data(filename):
    # Check if file exists before attempting to open it
    if not os.path.exists(filename):
        print(f"Error: File '{filename}' not found.")
        # Create sample data for demonstration
        sample_data = {
            "users": [
                {"id": 1, "friends": [2, 3]},
                {"id": 2, "friends": [1, 3, 4]},
                {"id": 3, "friends": [1, 2, 5]},
                {"id": 4, "friends": [2, 5]},
                {"id": 5, "friends": [3, 4]}
            ]
        }
        return sample_data
    
    # If file exists, load it normally
    with open(filename, "r") as file:
        return json.load(file)

def find_people_you_may_know(user_id, data):
    user_friends = {}
    for user in data["users"]:
        user_friends[user["id"]] = set(user["friends"])
    
    if user_id not in user_friends:
        return []
    
    direct_friends = user_friends[user_id]
    suggestions = {}
    
    for friend in direct_friends:
        # For all friends of friend
        for mutual in user_friends[friend]:
            # If mutual id is not the same user and not already a direct friend of user
            if mutual != user_id and mutual not in direct_friends:
                # Count mutual friends
                suggestions[mutual] = suggestions.get(mutual, 0) + 1
    
    sorted_suggestions = sorted(suggestions.items(), key=lambda x: x[1], reverse=True)
    return [user_id for user_id, _ in sorted_suggestions]

# Load data - now with error handling
data = load_data("cleaned_data2.json")
user_id = 1  # Example: Finding suggestions for Amit
recommendations = find_people_you_may_know(user_id, data)
print(f"People You May Know for User {user_id}: {recommendations}")
# Out:
# Error: File 'cleaned_codebook_data.json' not found.
# People You May Know for User 1: [4, 5]
